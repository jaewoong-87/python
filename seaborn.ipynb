# %% [markdown]
# <a href="https://colab.research.google.com/github/jaewoong-87/python/blob/master/seaborn.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# seaborn : statistical data visualization

# %%
import numpy as np
import pandas as pd
from scipy import stats
import matplotlib.pyplot as plt
import matplotlib as mpl
import seaborn as sns
sns.set(style='whitegrid')
sns.__version__
# Out:
# '0.11.1'

# %%
penguins = sns.load_dataset("penguins") 
penguins
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-39-8f15deacc022> in <module>()
# ----> 1 penguins = sns.load_dataset("penguins")
#       2 penguins
#
# TypeError: 'str' object is not callable

# %%
sns.relplot(x='bill_length_mm', y='bill_depth_mm', data=penguins);

# %%
sns.relplot(x='flipper_length_mm', y='body_mass_g', data=penguins);

# %%
sns.relplot(x='flipper_length_mm', y='body_mass_g',
            hue='species', col='island',data=penguins);

# %% [markdown]
# line plot
